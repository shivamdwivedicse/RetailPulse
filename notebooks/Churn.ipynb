# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("rfm_segments.csv")
df.head()
# Out:
#    Customer ID  Recency  Frequency  Monetary  Cluster        Segment
# 0        12347        1          8   4921.53        2      Champions
# 1        12348       74          5   2019.40        5        At risk
# 2        12349       18          4   4428.69        2      Champions
# 3        12350      309          1    334.40        4  Lost customer
# 4        12351      374          1    300.93        4  Lost customer

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (4989, 6)
# ['Customer ID', 'Recency', 'Frequency', 'Monetary', 'Cluster', 'Segment']

# %%
#check no of churned customers 

df['Churn'] = (df['Segment']=='At risk').astype(int)
df['Churn'].value_counts()
# Out:
# Churn
# 0    4321
# 1     668
# Name: count, dtype: int64

# %%
df['Churn'].value_counts(normalize = True)*100
# Out:
# Churn
# 0    86.610543
# 1    13.389457
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(5,5))
df['Churn'].value_counts().plot(kind = 'bar' , color = ["green",'red'])
plt.title("Churn Distribution" , fontsize = 12 , fontweight ='bold')
plt.xlabel("Churn (0=Active,1=Churned)")
plt.ylabel('Count')
plt.xticks(rotation = 0)
plt.tight_layout()
# plt.grid(True)
plt.show()

# %%
x = df[['Recency' , 'Frequency', 'Monetary']]
y = df['Churn']

# %%
print(x.shape) 
print(y.shape)
# Out:
# (4989, 3)
# (4989,)

# %%
#train test split 
from sklearn.model_selection import train_test_split
x = df[['Recency' , 'Frequency', 'Monetary']]
y = df['Churn']
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3991, 3)
# (998, 3)
# (3991,)
# (998,)

# %% [markdown]
# **It is very mendatory to apply SMOTE as the data is very imbalanced**

# %% [markdown]
# **ACTIVE = 86.6% and AT RISK = 13.4 %** ,
# **APPLYING SMOTE**

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42) #model 
x_train_sm , y_train_sm = sm.fit_resample(x_train , y_train)  #balanced the testing data

# %% [markdown]
# **Check counting before and after smote**

# %%
print("Before Smote:", y_train.value_counts().to_dict())
print("After Smote:", y_train_sm.value_counts().to_dict())
# Out:
# Before Smote: {0: 3475, 1: 516}
# After Smote: {0: 3475, 1: 3475}

# %% [markdown]
# **XG BOOST MODEL**

# %%
from xgboost import XGBClassifier
model = XGBClassifier(n_estimators = 100 , learning_rate=0.1,max_depth=4,random_state=42)
model.fit(x_train_sm,y_train_sm)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# **MODEL EVALUATION USING ROC-AUC SCORE**

# %%
from sklearn.metrics import roc_auc_score , classification_report , confusion_matrix
y_pred = model.predict(x_test)
# print(y_pred) 
y_prob = model.predict_proba(x_test)[:,1]
# y_prob 
auc = roc_auc_score(y_test , y_prob)
auc
# Out:
# np.float64(0.9999650055991043)

# %%
cm = confusion_matrix(y_test , y_pred)
cm
# Out:
# array([[845,   1],
#        [  3, 149]])

# %% [markdown]
# **CHECKING FOR OVERFITTING TRAINING AND TESTING ACCURACY**

# %%
train_score = model.score(x_train_sm , y_train_sm)
print(train_score)
test_score = model.score(x_test , y_test)
print(test_score)

print('No overfitting❌')
# Out:
# 0.9997122302158273
# 0.9959919839679359
# No overfitting❌

# %% [markdown]
# **CHECKING PRECISION @TOP20%**

# %%
top_20 = int(0.20*len(y_test))  #taking top 20 customers 
indices = np.argsort(y_prob)[::-1][:top_20] 
precision_top_20 = y_test.iloc[indices].sum()/top_20
precision_top_20
# Out:
# np.float64(0.7638190954773869)

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\shiva\anaconda3\lib\site-packages (0.52.0)
# Requirement already satisfied: numpy>=2 in c:\users\shiva\anaconda3\lib\site-packages (from shap) (2.1.3)
# Requirement already satisfied: scipy in c:\users\shiva\anaconda3\lib\site-packages (from shap) (1.15.3)
# Requirement already satisfied: scikit-learn in c:\users\shiva\anaconda3\lib\site-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in c:\users\shiva\anaconda3\lib\site-packages (from shap) (2.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\shiva\anaconda3\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\shiva\anaconda3\lib\site-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in c:\users\shiva\anaconda3\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in c:\users\shiva\anaconda3\lib\site-packages (from shap) (0.61.0)
# Requirement already satisfied: llvmlite in c:\users\shiva\anaconda3\lib\site-packages (from shap) (0.44.0)
# Requirement already satisfied: cloudpickle in c:\users\shiva\anaconda3\lib\site-packages (from shap) (3.0.0)
# Requirement already satisfied: colorama in c:\users\shiva\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shiva\anaconda3\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shiva\anaconda3\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shiva\anaconda3\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\shiva\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\shiva\anaconda3\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shiva\anaconda3\lib\site-packages (from scikit-learn->shap) (3.5.0)

# %%
import shap

# %% [markdown]
# **SHAP VALUES**

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(x_test)

# %% [markdown]
# **Shap Summary plot**

# %%
shap.summary_plot(shap_values , x_test)

# %% [markdown]
# **Bar plot**

# %%
shap.summary_plot(shap_values , x_test , plot_type='bar')

# %% [markdown]
# **TESTING**

# %%
new_customer = pd.DataFrame({
    'Recency':[180], 
    'Frequency':[4], 
    'Monetary':[1500]
})

pred = model.predict(new_customer)
print("At Risk"if pred[0]==1 else "Active")
# Out:
# At Risk

# %% [markdown]
# **LIST OF AT RISK CUSTOMER**

# %%
at_risk = df[df['Churn']==1]
at_risk.to_csv('at_risk_customer.csv' , index = False)

# %%
import pickle
with open('churn_model.pkl','wb') as f:
    pickle.dump(model , f)
print("Your model is saved")
# Out:
# Your model is saved
